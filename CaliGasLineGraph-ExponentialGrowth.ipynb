# %%
# Import Dependencies 
import matplotlib.pyplot as plt
import numpy as np

# %%
# Create the X and Y axis lists
time = np.arange(1 ,48, 0.1)
price_gallon = [3.879, 3.699, 4.399, 3.679, 3.999, 3.859, 4.159, 4.399, 4.499, 3.399, 3.739, 4.299, 3.559, 3.559, 3.489, 3.299, 3.199,
3.239, 3.259, 3.299, 3.229, 3.219, 3.199, 3.459, 3.999, 3.859, 3.439, 3.639, 3.499, 3.899, 3.599, 3.619,
3.559, 3.429, 3.839, 3.399, 3.739, 3.999, 3.359, 3.399, 3.319, 3.299, 3.439, 3.239, 3.699, 3.799, 3.159, 3.399]
price_total = [67.41, 66.73, 20.07, 54.57, 15.00, 35.00, 19.93, 25.01, 10.00, 54.45, 64.88, 12.02, 63.25, 20.04,
59.95, 55.14, 44.84, 57.20, 51.18, 53.29, 51.11, 52.29, 27.90, 62.29, 12.00, 65.73, 66.37, 66.22, 20.00, 27.55, 15.47, 
              15.01, 62.03, 54.75, 60.46, 56.32, 58.08, 14.75, 60.67, 49.81, 24.22, 46.94, 20.00, 41.95, 10.01, 60.63,
              33.66, 25.00]

# %%
#Create an exponential series of values which we can then chart
e_x = [np.exp(x) for x in price_gallon]
e_x
# Out:
# [48.37581506031268,
#  40.406877272619965,
#  81.36945850816574,
#  39.60676749509097,
#  54.5435791730887,
#  47.417909742251446,
#  64.00748310242206,
#  81.36945850816574,
#  89.9271591627878,
#  29.93415092440687,
#  42.05591321681241,
#  73.62613074351285,
#  35.12805152370102,
#  35.12805152370102,
#  32.75317814603655,
#  27.085539833539045,
#  24.5080099290896,
#  25.508200788210488,
#  26.023500625803887,
#  27.085539833539045,
#  25.254389949608196,
#  25.003104571046247,
#  24.5080099290896,
#  31.785175441339778,
#  54.5435791730887,
#  47.417909742251446,
#  31.155786798423712,
#  38.05376392824492,
#  33.08235305894174,
#  49.35307134941751,
#  36.561654502253354,
#  37.300248916794146,
#  35.12805152370102,
#  30.845781540103914,
#  46.47897222033433,
#  29.93415092440687,
#  42.05591321681241,
#  54.5435791730887,
#  28.760416078161875,
#  29.93415092440687,
#  27.632704033524607,
#  27.085539833539045,
#  31.155786798423712,
#  25.508200788210488,
# ...

# %%
# Create a graph based upon the two lists we have created
plt.plot(price_gallon, e_x)

# %%
# Give our graph axis labels
plt.xlabel("Price/Gallon")
plt.ylabel("Amount spent on Gas")

# Have to plot our chart once again as it doesn't stick after being shown
plt.plot(price_gallon, e_x)
plt.show()

# %%
# Add labels to X and Y axes :: Add title
plt.title("California Gas Prices in Last Year")
plt.xlabel("Price per Gallon")
plt.ylabel("Date")
# Out:
# Text(0, 0.5, 'Date')

# %%
# Set the limits for the X and Y axes
plt.xlim(0,120)
plt.ylim(5,95)
# Out:
# (5, 95)

# %%
# Create a legend for the chart
plt.legend(handles=[price_gallon, price_total], loc="best")
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-8-3978291d77e2> in <module>
#       1 # Create a legend for the chart
# ----> 2 plt.legend(handles=[price_gallon, price_total], loc="best")
#
# ~\anaconda\Anaconda3\lib\site-packages\matplotlib\pyplot.py in legend(*args, **kwargs)
#    2690 @docstring.copy(Axes.legend)
#    2691 def legend(*args, **kwargs):
# -> 2692     return gca().legend(*args, **kwargs)
#    2693
#    2694
#
# ~\anaconda\Anaconda3\lib\site-packages\matplotlib\axes\_axes.py in legend(self, *args, **kwargs)
#     401                 [self],
#     402                 *args,
# --> 403                 **kwargs)
#     404         if len(extra_args):
#     405             raise TypeError('legend only accepts two non-keyword arguments')
#
# ...

# %%
# Add in a grid for the chart
plt.grid()

# %%
# Saves an image of our chart so that we can view it in a folder
plt.savefig("../Images/ExponentialGrowthCaliGas.png")
plt.show()
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-11-ea0f6f2cbdc8> in <module>
#       1 # Saves an image of our chart so that we can view it in a folder
# ----> 2 plt.savefig("../Images/ExponentialGrowthCaliGas.png")
#       3 plt.show()
#
# ~\anaconda\Anaconda3\lib\site-packages\matplotlib\pyplot.py in savefig(*args, **kwargs)
#     727 def savefig(*args, **kwargs):
#     728     fig = gcf()
# --> 729     res = fig.savefig(*args, **kwargs)
#     730     fig.canvas.draw_idle()   # need this if 'transparent=True' to reset colors
#     731     return res
#
# ~\anaconda\Anaconda3\lib\site-packages\matplotlib\figure.py in savefig(self, fname, transparent, **kwargs)
#    2178             self.patch.set_visible(frameon)
#    2179
# -> 2180         self.canvas.print_figure(fname, **kwargs)
#    2181
#    2182         if frameon:
#
# ...
